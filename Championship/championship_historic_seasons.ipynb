# %% [markdown]
# # Get League Table and Stats

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
import numpy as np

# %%
# URL of the website
url = "https://fbref.com/en/comps/10/2022-2023/2022-2023-Championship-Stats"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
    # Parse the HTML content of the page
soup = BeautifulSoup(response.text, "html.parser")

    # Find the table using its HTML class
table = soup.find("table", {"class": "stats_table"})

    # Extract table data into a list of lists
table_data = []
for row in table.find_all("tr"):
    row_data = [cell.text.strip() for cell in row.find_all(["th", "td"])]
    table_data.append(row_data)

    # Create a DataFrame from the list of lists
columns = table_data[0]  # Assuming the first row contains column headers
data = table_data[1:]
league_table_df = pd.DataFrame(data, columns=columns)

# %% [markdown]
# # Get Fixtures

# %%
# URL of the website
url = "https://fbref.com/en/comps/10/2022-2023/schedule/2022-2023-Championship-Scores-and-Fixtures"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, "html.parser")

    # Find the table containing fixtures
    table = soup.find("table", {"class": "stats_table"})

    # Extract data into a list of dictionaries
    fixtures_data = []
    for row in table.find_all("tr")[1:]:  # Skip the header row
        columns = row.find_all(["th", "td"])
        
         # Extracting specific columns based on the structure of the table
        fixture_type = columns[0].text.strip()
        matchday = columns[1].text.strip()
        weekday = columns[2].text.strip()
        date = columns[3].text.strip()
        time = columns[4].text.strip()
        home_team = columns[5].text.strip()
        home_xG = columns[6].text.strip()
        result = columns[7].text.strip()
        away_team = columns[8].text.strip()
        away_xG = columns[9].text.strip()
        attendance = columns[10].text.strip()
        stadium = columns[11].text.strip()
        referee = columns[12].text.strip()

        fixture_info = {
            "fixture_type": fixture_type,
            "matchday": matchday,
            "weekday": weekday,
            "date": date,
            "time": time,
            "home_team": home_team,
            "home_xG": home_xG,
            "result": result,
            "away_xG": away_xG,
            "away_team": away_team,
            "attendance": attendance,
            "stadium": stadium,
            "referee": referee,
            "competition": English Championship
        }

        fixtures_data.append(fixture_info)

    # Create a DataFrame from the list of dictionaries
    fixtures_table = pd.DataFrame(fixtures_data)

# %%
fixtures_table.head()
#need to fix from attendance on
# Out:
#      fixture_type matchday weekday        date   time      home_team home_xG  \
# 0  Regular season        1     Fri  2022-07-29  20:00   Huddersfield     0.1
# 1  Regular season        1     Sat  2022-07-30  15:00      Hull City     1.5
# 2  Regular season        1     Sat  2022-07-30  15:00  Rotherham Utd     0.6
# 3  Regular season        1     Sat  2022-07-30  15:00       Millwall     0.8
# 4  Regular season        1     Sat  2022-07-30  15:00     Luton Town     1.4
#
#   result          away_xG away_team attendance                   stadium  \
# 0    0–1          Burnley       1.1     20,206  The John Smith's Stadium
# 1    2–1     Bristol City       1.0     16,667               MKM Stadium
# 2    1–1     Swansea City       0.6     10,454  AESSEAL New York Stadium
# 3    2–0       Stoke City       0.2     15,341                   The Den
# 4    0–0  Birmingham City       0.7      9,921   Kenilworth Road Stadium
#
#            referee
# 0  James Linington
# 1  Dean Whitestone
# 2     Matt Donohue
# 3     Keith Stroud
# 4     Graham Scott

# %%
fixtures_table['is_game_complete'] = np.where(len(fixtures_table['result']) > 0, 1, 0)

# %% [markdown]
# # Getting Game IDs

# %%
# Parse the HTML content of the page
soup = BeautifulSoup(response.text, 'html.parser')

# Find all <td> elements with data-stat="score"
score_cells = soup.find_all('td', {'data-stat': 'score'})

# Extract game IDs from the <a> tags within the score_cells, the third element is the game ID
game_ids = [cell.find('a')['href'].split('/')[3] for cell in score_cells if cell.find('a')]
# Then strip the white space in the IDs
game_ids = [x.strip(' ') for x in game_ids]

# %%
game_ids = game_ids[0:4]
#just use three to test
#next

# %% [markdown]
# # Scraping Shot Data

# %%
all_data = []
for unique_id in game_ids:
    # URL of the page to scrape
    url = f'https://fbref.com/en/matches/{unique_id}/'

    # Get the game ID from the URL
    game_id = url.split("/")[-2]

    # Send a GET request to the URL
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")

    # Find the Shots table on the page
    shots_table = soup.find("div", {"id": "switcher_shots"})

    # Create empty lists to store data and create the columns
    data = []
    headers = ['Game_ID', 'Minute', 'Player', 'Team', 'xG', 'PSxG', 'Result', 'Distance', 'Body Part', 'Notes', 'SCA 1 Player', 'Event 1', 'SCA 2 Player', 'Event 2']

    # Extract table rows
    rows = shots_table.find("tbody").find_all("tr")
    for row in rows:
        row_data = [game_id] + [cell.get_text().strip() for cell in row.find_all(["th", "td"])]
        data.append(row_data)

    # Create a DataFrame from the scraped data
    shots_df = pd.DataFrame(data, columns=headers)

    # Find the home and away teams and formations
    team_headers = soup.find_all("th", {"colspan": "2"})
    teams = [header.text.strip().split(" (")[0] for header in team_headers if "(" in header.text.strip()]
    formations = [header.text.strip().split(" (")[1][:-1] for header in team_headers if "(" in header.text.strip()]

    # Extracting the home and away teams and formations
    home_team = teams[0]
    away_team = teams[1]
    home_formation = formations[0]
    away_formation = formations[1]

    # Find the competition -- only using .find because there are multiple in the HTML and we only need one, then take only the text
    competition = soup.find("a", {"href": "/en/comps/10/2022-2023/2022-2023-Championship-Stats"}).text

    # Extract the match date and add to df, this one is a little tricky as it's hidden within the span tag
    span_venuetime = soup.find("span", class_="venuetime")
    match_date = span_venuetime.get("data-venue-date") if span_venuetime else None

    #Get location, 4th element in that list
    location = soup.find("div", {"class": "scorebox_meta"}).find_all("small")[3].text
    
    all_data.append(data)

# %%
all_data
# Out:
# [['46d9048f',
#   '11',
#   'Josh Cullen',
#   'Burnley',
#   '0.07',
#   '0.02',
#   'Saved',
#   '21',
#   'Left Foot',
#   '',
#   'Ian Maatsen',
#   'Pass (Live)',
#   'Josh Cullen',
#   'Pass (Live)'],
#  ['46d9048f',
#   '14',
#   'Ashley Barnes',
#   'Burnley',
#   '0.06',
#   '0.34',
#   'Saved',
#   '14',
#   'Right Foot',
#   '',
#   'Dara Costelloe',
#   'Pass (Live)',
#   'Josh Brownhill',
#   'Pass (Live)'],
#  ['46d9048f',
#   '18',
#   'Ian Maatsen',
#   'Burnley',
#   '0.05',
#   '0.28',
#   'Goal',
#   '15',
#   'Right Foot',
#   'Deflected',
#   'Josh Brownhill',
#   'Pass (Live)',
#   'Ian Maatsen',
#   'Pass (Live)'],
#  ['46d9048f',
#   '20',
#   'Connor Roberts',
#   'Burnley',
#   '0.21',
#   '0.88',
#   'Saved',
#   '6',
#   'Right Foot',
#   'Volley',
#   'Josh Cullen',
#   'Pass (Live)',
#   'Connor Roberts',
#   'Pass (Live)'],
#  ['46d9048f',
#   '24',
#   'Josh Brownhill',
#   'Burnley',
#   '0.03',
#   '0.20',
#   'Saved',
#   '18',
#   'Right Foot',
#   'Volley',
#   'Dara Costelloe',
#   'Fouled',
#   '',
#   ''],
#  ['46d9048f',
#   '38',
#   'Josh Koroma',
#   'Huddersfield',
#   '0.04',
#   '',
#   'Blocked',
#   '18',
#   'Right Foot',
#   '',
#   'Duane Holmes',
#   'Pass (Live)',
#   'Jonathan Hogg',
#   'Pass (Live)'],
#  ['46d9048f',
#   '40',
#   'Dara Costelloe',
#   'Burnley',
#   '0.23',
#   '',
#   'Off Target',
#   '12',
#   'Right Foot',
#   'Volley',
#   'Ian Maatsen',
#   'Pass (Live)',
#   'Josh Brownhill',
#   'Pass (Live)'],
#  ['46d9048f',
#   '44',
#   'Samuel Bastien',
#   'Burnley',
#   '0.06',
#   '',
#   'Blocked',
#   '21',
#   'Left Foot',
#   '',
#   'Ian Maatsen',
#   'Pass (Live)',
#   'Samuel Bastien',
#   'Pass (Live)'],
#  ['46d9048f',
#   '45',
#   'Dara Costelloe',
#   'Burnley',
#   '0.06',
#   '',
#   'Off Target',
#   '18',
#   'Left Foot',
#   '',
#   'Ian Maatsen',
#   'Pass (Live)',
#   'Samuel Bastien',
#   'Shot'],
#  ['46d9048f', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['46d9048f',
#   '69',
#   'Josh Brownhill',
#   'Burnley',
#   '0.03',
#   '',
#   'Off Target',
#   '29',
#   'Right Foot',
#   '',
#   'Ian Maatsen',
#   'Pass (Live)',
#   'Taylor Harwood-Bellis',
#   'Pass (Live)'],
#  ['46d9048f',
#   '74',
#   'Danny Ward',
#   'Huddersfield',
#   '0.05',
#   '',
#   'Off Target',
#   '18',
#   'Left Foot',
#   'Volley',
#   '',
#   '',
#   '',
#   ''],
#  ['46d9048f',
#   '76',
#   'Taylor Harwood-Bellis',
#   'Burnley',
#   '0.04',
#   '0.11',
#   'Saved',
#   '8',
#   'Head',
#   '',
#   'Charlie Taylor',
#   'Pass (Live)',
#   'Charlie Taylor',
#   'Pass (Live)'],
#  ['46d9048f',
#   '77',
#   'Ian Maatsen',
#   'Burnley',
#   '0.02',
#   '',
#   'Off Target',
#   '27',
#   'Left Foot',
#   '',
#   'Josh Cullen',
#   'Pass (Live)',
#   '',
#   ''],
#  ['46d9048f',
#   '80',
#   'Scott Twine',
#   'Burnley',
#   '0.05',
#   '',
#   'Blocked',
#   '14',
#   'Left Foot',
#   '',
#   'Ian Maatsen',
#   'Pass (Live)',
#   'Josh Brownhill',
#   'Pass (Live)'],
#  ['46d9048f',
#   '82',
#   'Vitinho',
#   'Burnley',
#   '0.04',
#   '',
#   'Blocked',
#   '18',
#   'Left Foot',
#   'Volley',
#   'Vitinho',
#   'Fouled',
#   'Ashley Barnes',
#   'Pass (Live)'],
#  ['46d9048f',
#   '83',
#   'Charlie Taylor',
#   'Burnley',
#   '0.00',
#   '',
#   'Off Target',
#   '20',
#   'Left Foot',
#   'Volley',
#   'Vitinho',
#   'Pass (Live)',
#   'Ian Maatsen',
#   'Pass (Live)'],
#  ['46d9048f',
#   '85',
#   'Scott Twine',
#   'Burnley',
#   '0.09',
#   '',
#   'Woodwork',
#   '23',
#   'Right Foot',
#   'Free kick',
#   'Vitinho',
#   'Fouled',
#   'Scott Twine',
#   'Pass (Live)'],
#  ['46d9048f',
#   '90+1',
#   'Ian Maatsen',
#   'Burnley',
#   '0.02',
#   '0.02',
#   'Saved',
#   '24',
#   'Left Foot',
#   'Volley',
#   'Scott Twine',
#   'Pass (Live)',
#   'Connor Roberts',
#   'Pass (Dead)'],
#  ['03cea9be',
#   '5',
#   'Matty James',
#   'Bristol City',
#   '0.05',
#   '0.07',
#   'Saved',
#   '9',
#   'Head',
#   '',
#   'Mark Sykes',
#   'Pass (Live)',
#   'Mark Sykes',
#   'Take-On'],
#  ['03cea9be',
#   '6',
#   'Chris Martin',
#   'Bristol City',
#   '0.10',
#   '',
#   'Off Target',
#   '7',
#   'Head',
#   '',
#   'Mark Sykes',
#   'Pass (Live)',
#   'Joe Williams',
#   'Pass (Live)'],
#  ['03cea9be',
#   '21',
#   'Jean Seri',
#   'Hull City',
#   '0.02',
#   '',
#   'Blocked',
#   '34',
#   'Right Foot',
#   '',
#   'Ozan Tufan',
#   'Pass (Live)',
#   'Allahyar Sayyadmanesh',
#   'Pass (Live)'],
#  ['03cea9be',
#   '25',
#   'Ozan Tufan',
#   'Hull City',
#   '0.06',
#   '',
#   'Blocked',
#   '26',
#   'Right Foot',
#   '',
#   'Jean Seri',
#   'Pass (Live)',
#   'Tyler Smith',
#   'Pass (Live)'],
#  ['03cea9be',
#   '30',
#   'Andreas Weimann',
#   'Bristol City',
#   '0.41',
#   '0.61',
#   'Goal',
#   '6',
#   'Right Foot',
#   '',
#   'Zak Vyner',
#   'Pass (Live)',
#   'Kal Naismith',
#   'Pass (Dead)'],
#  ['03cea9be',
#   '32',
#   'Alex Scott',
#   'Bristol City',
#   '0.07',
#   '0.04',
#   'Saved',
#   '28',
#   'Right Foot',
#   '',
#   'Joe Williams',
#   'Pass (Live)',
#   'Andreas Weimann',
#   'Pass (Live)'],
#  ['03cea9be',
#   '36',
#   'Oscar Estupiñan',
#   'Hull City',
#   '0.21',
#   '0.38',
#   'Saved',
#   '11',
#   'Left Foot',
#   '',
#   'Jean Seri',
#   'Pass (Live)',
#   'Jacob Greaves',
#   'Pass (Live)'],
#  ['03cea9be',
#   '39',
#   'Ozan Tufan',
#   'Hull City',
#   '0.03',
#   '',
#   'Blocked',
#   '31',
#   'Right Foot',
#   '',
#   'Jean Seri',
#   'Pass (Live)',
#   'Oscar Estupiñan',
#   'Pass (Live)'],
#  ['03cea9be',
#   '43',
#   'Alfie Jones',
#   'Hull City',
#   '0.04',
#   '',
#   'Blocked',
#   '24',
#   'Right Foot',
#   '',
#   'Allahyar Sayyadmanesh',
#   'Pass (Live)',
#   '',
#   ''],
#  ['03cea9be',
#   '45+2',
#   'Ozan Tufan',
#   'Hull City',
#   '0.02',
#   '',
#   'Off Target',
#   '27',
#   'Right Foot',
#   'Volley',
#   'Jean Seri',
#   'Pass (Dead)',
#   'Jean Seri',
#   'Pass (Live)'],
#  ['03cea9be',
#   '45+2',
#   'Allahyar Sayyadmanesh',
#   'Hull City',
#   '0.06',
#   '',
#   'Blocked',
#   '7',
#   'Right Foot',
#   '',
#   'Tobias Figueiredo',
#   'Pass (Live)',
#   'Alfie Jones',
#   'Pass (Live)'],
#  ['03cea9be',
#   '45+2',
#   'Oscar Estupiñan',
#   'Hull City',
#   '0.12',
#   '',
#   'Blocked',
#   '12',
#   'Left Foot',
#   '',
#   'Jean Seri',
#   'Pass (Live)',
#   'Allahyar Sayyadmanesh',
#   'Shot'],
#  ['03cea9be', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['03cea9be',
#   '52',
#   'Mark Sykes',
#   'Bristol City',
#   '0.02',
#   '',
#   'Off Target',
#   '31',
#   'Right Foot',
#   'Volley',
#   '',
#   '',
#   '',
#   ''],
#  ['03cea9be',
#   '54',
#   'Ozan Tufan',
#   'Hull City',
#   '0.07',
#   '',
#   'Woodwork',
#   '20',
#   'Right Foot',
#   '',
#   'Alfie Jones',
#   'Pass (Live)',
#   '',
#   ''],
#  ['03cea9be',
#   '57',
#   'Jacob Greaves',
#   'Hull City',
#   '0.02',
#   '0.02',
#   'Saved',
#   '13',
#   'Head',
#   '',
#   'Jean Seri',
#   'Pass (Dead)',
#   '',
#   ''],
#  ['03cea9be',
#   '61',
#   'Andreas Weimann',
#   'Bristol City',
#   '0.03',
#   '',
#   'Off Target',
#   '9',
#   'Right Foot',
#   'Volley',
#   'Jay Dasilva',
#   'Pass (Live)',
#   'Tommy Conway',
#   'Pass (Live)'],
#  ['03cea9be',
#   '65',
#   'Tyler Smith',
#   'Hull City',
#   '0.02',
#   '',
#   'Off Target',
#   '33',
#   'Right Foot',
#   '',
#   'Jean Seri',
#   'Pass (Live)',
#   'Tyler Smith',
#   'Pass (Live)'],
#  ['03cea9be',
#   '69',
#   'Tommy Conway',
#   'Bristol City',
#   '0.06',
#   '',
#   'Off Target',
#   '12',
#   'Right Foot',
#   '',
#   'Kane Wilson',
#   'Pass (Live)',
#   'Tommy Conway',
#   'Pass (Live)'],
#  ['03cea9be',
#   '72',
#   'Ozan Tufan (pen)',
#   'Hull City',
#   '0.79',
#   '1.00',
#   'Goal',
#   '13',
#   'Right Foot',
#   '',
#   'Benjamin Tetteh',
#   'Fouled',
#   'Lewie Coyle',
#   'Pass (Live)'],
#  ['03cea9be',
#   '86',
#   'Jay Dasilva',
#   'Bristol City',
#   '0.05',
#   '',
#   'Off Target',
#   '15',
#   'Left Foot',
#   '',
#   'Andreas Weimann',
#   'Pass (Live)',
#   'Zak Vyner',
#   'Pass (Live)'],
#  ['03cea9be',
#   '88',
#   'Tommy Conway',
#   'Bristol City',
#   '0.10',
#   '',
#   'Blocked',
#   '16',
#   'Right Foot',
#   '',
#   'Kane Wilson',
#   'Pass (Live)',
#   'Kal Naismith',
#   'Pass (Live)'],
#  ['03cea9be',
#   '90+2',
#   'Andreas Weimann',
#   'Bristol City',
#   '0.09',
#   '0.03',
#   'Saved',
#   '10',
#   'Right Foot',
#   '',
#   'Kane Wilson',
#   'Pass (Live)',
#   'Timm Klose',
#   'Pass (Live)'],
#  ['03cea9be',
#   '90+4',
#   'Jean Seri',
#   'Hull City',
#   '0.03',
#   '0.12',
#   'Goal',
#   '30',
#   'Right Foot',
#   'Deflected',
#   '',
#   '',
#   '',
#   ''],
#  ['03cea9be',
#   '90+7',
#   'Greg Docherty',
#   'Hull City',
#   '0.06',
#   '',
#   'Off Target',
#   '11',
#   'Left Foot',
#   '',
#   'Tobias Figueiredo',
#   'Pass (Live)',
#   'Greg Docherty',
#   'Pass (Live)'],
#  ['78f52c96',
#   '4',
#   'Matthew Sorinola',
#   'Swansea City',
#   '0.03',
#   '',
#   'Blocked',
#   '18',
#   'Right Foot',
#   '',
#   'Jamie Paterson',
#   'Pass (Live)',
#   'Joël Piroe',
#   'Pass (Live)'],
#  ['78f52c96',
#   '7',
#   'Joël Piroe',
#   'Swansea City',
#   '0.02',
#   '0.03',
#   'Saved',
#   '25',
#   'Left Foot',
#   '',
#   'Joël Latibeaudière',
#   'Pass (Live)',
#   'Harry Darling',
#   'Pass (Live)'],
#  ['78f52c96',
#   '13',
#   'Joël Piroe',
#   'Swansea City',
#   '0.07',
#   '',
#   'Blocked',
#   '21',
#   'Left Foot',
#   '',
#   'Matt Grimes',
#   'Pass (Live)',
#   'Michael Obafemi',
#   'Pass (Live)'],
#  ['78f52c96',
#   '16',
#   'Chiedozie Ogbene',
#   'Rotherham Utd',
#   '0.06',
#   '0.23',
#   'Goal',
#   '4',
#   'Head',
#   '',
#   'Grant Hall',
#   'Pass (Live)',
#   '',
#   ''],
#  ['78f52c96',
#   '19',
#   'Conor Washington',
#   'Rotherham Utd',
#   '0.06',
#   '0.03',
#   'Saved',
#   '20',
#   'Right Foot',
#   'Deflected',
#   'Daniel Barlaser',
#   'Pass (Live)',
#   'Grant Hall',
#   'Pass (Live)'],
#  ['78f52c96',
#   '25',
#   'Chiedozie Ogbene',
#   'Rotherham Utd',
#   '0.11',
#   '0.65',
#   'Saved',
#   '8',
#   'Right Foot',
#   'Volley',
#   'Wes Harding',
#   'Pass (Live)',
#   'Daniel Barlaser',
#   'Pass (Live)'],
#  ['78f52c96',
#   '31',
#   'Harry Darling',
#   'Swansea City',
#   '0.01',
#   '',
#   'Blocked',
#   '36',
#   'Right Foot',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['78f52c96',
#   '38',
#   'Harry Darling',
#   'Swansea City',
#   '0.01',
#   '0.40',
#   'Goal',
#   '33',
#   'Right Foot',
#   '',
#   'Matt Grimes',
#   'Pass (Live)',
#   'Joël Latibeaudière',
#   'Pass (Live)'],
#  ['78f52c96',
#   '43',
#   'Jamie Paterson',
#   'Swansea City',
#   '0.02',
#   '0.02',
#   'Saved',
#   '31',
#   'Right Foot',
#   '',
#   'Matt Grimes',
#   'Pass (Live)',
#   'Joël Latibeaudière',
#   'Pass (Live)'],
#  ['78f52c96',
#   '45+2',
#   'Nathan Wood-Gordon',
#   'Swansea City',
#   '0.05',
#   '',
#   'Off Target',
#   '11',
#   'Head',
#   '',
#   'Jamie Paterson',
#   'Pass (Dead)',
#   'Nathan Wood-Gordon',
#   'Fouled'],
#  ['78f52c96', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['78f52c96',
#   '46',
#   'Conor Washington',
#   'Rotherham Utd',
#   '0.02',
#   '',
#   'Blocked',
#   '28',
#   'Right Foot',
#   '',
#   'Daniel Barlaser',
#   'Pass (Live)',
#   'Ben Wiles',
#   'Pass (Dead)'],
#  ['78f52c96',
#   '50',
#   'Chiedozie Ogbene',
#   'Rotherham Utd',
#   '0.08',
#   '0.19',
#   'Saved',
#   '16',
#   'Right Foot',
#   '',
#   'Ben Wiles',
#   'Pass (Live)',
#   'Jamie Lindsay',
#   'Interception'],
#  ['78f52c96',
#   '58',
#   'Matt Grimes',
#   'Swansea City',
#   '0.01',
#   '',
#   'Blocked',
#   '32',
#   'Left Foot',
#   '',
#   'Joël Piroe',
#   'Pass (Live)',
#   'Matt Grimes',
#   'Pass (Live)'],
#  ['78f52c96',
#   '58',
#   'Joël Latibeaudière',
#   'Swansea City',
#   '0.07',
#   '',
#   'Off Target',
#   '8',
#   'Head',
#   '',
#   'Jamie Paterson',
#   'Pass (Live)',
#   'Matt Grimes',
#   'Pass (Live)'],
#  ['78f52c96',
#   '64',
#   'Joël Piroe',
#   'Swansea City',
#   '0.05',
#   '',
#   'Blocked',
#   '15',
#   'Right Foot',
#   '',
#   'Joël Piroe',
#   'Take-On',
#   'Matt Grimes',
#   'Pass (Live)'],
#  ['78f52c96',
#   '64',
#   'Jamie Paterson',
#   'Swansea City',
#   '0.16',
#   '0.19',
#   'Saved',
#   '15',
#   'Left Foot',
#   '',
#   'Michael Obafemi',
#   'Pass (Live)',
#   'Joël Piroe',
#   'Shot'],
#  ['78f52c96',
#   '69',
#   'Georgie Kelly',
#   'Rotherham Utd',
#   '0.02',
#   '0.04',
#   'Saved',
#   '15',
#   'Right Foot',
#   '',
#   'Georgie Kelly',
#   'Interception',
#   '',
#   ''],
#  ['78f52c96',
#   '77',
#   'Joël Piroe',
#   'Swansea City',
#   '0.05',
#   '',
#   'Off Target',
#   '16',
#   'Left Foot',
#   '',
#   'Jay Fulton',
#   'Pass (Live)',
#   'Olivier Ntcham',
#   'Pass (Live)'],
#  ['78f52c96',
#   '78',
#   'Cohen Bramall',
#   'Rotherham Utd',
#   '0.09',
#   '0.18',
#   'Saved',
#   '11',
#   'Left Foot',
#   '',
#   'Daniel Barlaser',
#   'Pass (Live)',
#   'Chiedozie Ogbene',
#   'Pass (Live)'],
#  ['78f52c96',
#   '88',
#   'Daniel Barlaser',
#   'Rotherham Utd',
#   '0.08',
#   '0.04',
#   'Saved',
#   '24',
#   'Right Foot',
#   '',
#   'Chiedozie Ogbene',
#   'Pass (Live)',
#   'Cohen Bramall',
#   'Pass (Live)'],
#  ['78f52c96',
#   '89',
#   'Georgie Kelly',
#   'Rotherham Utd',
#   '0.11',
#   '0.35',
#   'Saved',
#   '9',
#   'Head',
#   '',
#   'Cohen Bramall',
#   'Pass (Dead)',
#   'Daniel Barlaser',
#   'Shot'],
#  ['78f52c96',
#   '90+6',
#   'Olivier Ntcham',
#   'Swansea City',
#   '0.00',
#   '',
#   'Blocked',
#   '37',
#   'Right Foot',
#   '',
#   'Harry Darling',
#   'Pass (Live)',
#   '',
#   ''],
#  ['78f52c96',
#   '90+6',
#   'Joël Piroe',
#   'Swansea City',
#   '0.02',
#   '0.22',
#   'Saved',
#   '31',
#   'Left Foot',
#   '',
#   'Matt Grimes',
#   'Pass (Live)',
#   'Joël Piroe',
#   'Pass (Live)'],
#  ['8cdd19be',
#   '12',
#   'Charlie Cresswell',
#   'Millwall',
#   '0.06',
#   '0.04',
#   'Goal',
#   '10',
#   'Head',
#   '',
#   'George Honeyman',
#   'Pass (Dead)',
#   'George Honeyman',
#   'Pass (Live)'],
#  ['8cdd19be',
#   '22',
#   'Scott Malone',
#   'Millwall',
#   '0.06',
#   '',
#   'Blocked',
#   '11',
#   'Left Foot',
#   '',
#   'Scott Malone',
#   'Take-On',
#   'Scott Malone',
#   'Take-On'],
#  ['8cdd19be',
#   '22',
#   'Murray Wallace',
#   'Millwall',
#   '0.02',
#   '',
#   'Off Target',
#   '16',
#   'Head',
#   '',
#   'George Honeyman',
#   'Pass (Live)',
#   'Scott Malone',
#   'Shot'],
#  ['8cdd19be',
#   '32',
#   'Charlie Cresswell',
#   'Millwall',
#   '0.10',
#   '',
#   'Off Target',
#   '7',
#   'Head',
#   '',
#   'Scott Malone',
#   'Pass (Dead)',
#   'George Honeyman',
#   'Fouled'],
#  ['8cdd19be',
#   '33',
#   'Tyrese Campbell',
#   'Stoke City',
#   '0.03',
#   '0.05',
#   'Saved',
#   '30',
#   'Left Foot',
#   '',
#   'Harry Clarke',
#   'Pass (Live)',
#   'Lewis Baker',
#   'Tackle'],
#  ['8cdd19be',
#   '45',
#   'George Honeyman',
#   'Millwall',
#   '0.04',
#   '',
#   'Blocked',
#   '26',
#   'Right Foot',
#   'Free kick',
#   'Benik Afobe',
#   'Fouled',
#   'Tom Bradshaw',
#   'Pass (Live)'],
#  ['8cdd19be',
#   '45',
#   'Murray Wallace',
#   'Millwall',
#   '0.02',
#   '',
#   'Off Target',
#   '14',
#   'Head',
#   '',
#   'George Honeyman',
#   'Pass (Dead)',
#   'George Honeyman',
#   'Shot'],
#  ['8cdd19be', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#  ['8cdd19be',
#   '47',
#   'Benik Afobe',
#   'Millwall',
#   '0.06',
#   '',
#   'Off Target',
#   '16',
#   'Left Foot',
#   '',
#   'Benik Afobe',
#   'Take-On',
#   'Billy Mitchell',
#   'Pass (Live)'],
#  ['8cdd19be',
#   '48',
#   'Tom Bradshaw',
#   'Millwall',
#   '0.06',
#   '0.09',
#   'Saved',
#   '11',
#   'Right Foot',
#   '',
#   'Murray Wallace',
#   'Pass (Live)',
#   '',
#   ''],
#  ['8cdd19be',
#   '51',
#   'Tom Bradshaw',
#   'Millwall',
#   '0.02',
#   '',
#   'Blocked',
#   '10',
#   'Head',
#   '',
#   'Scott Malone',
#   'Pass (Dead)',
#   '',
#   ''],
#  ['8cdd19be',
#   '56',
#   'Josh Laurent',
#   'Stoke City',
#   '0.02',
#   '',
#   'Off Target',
#   '30',
#   'Right Foot',
#   '',
#   'Harry Clarke',
#   'Pass (Live)',
#   'Lewis Baker',
#   'Pass (Live)'],
#  ['8cdd19be',
#   '57',
#   'Scott Malone',
#   'Millwall',
#   '0.04',
#   '0.02',
#   'Saved',
#   '31',
#   'Left Foot',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['8cdd19be',
#   '65',
#   'Charlie Cresswell',
#   'Millwall',
#   '0.08',
#   '0.04',
#   'Saved',
#   '9',
#   'Head',
#   '',
#   'Scott Malone',
#   'Pass (Dead)',
#   '',
#   ''],
#  ['8cdd19be',
#   '65',
#   'Charlie Cresswell',
#   'Millwall',
#   '0.18',
#   '0.45',
#   'Goal',
#   '8',
#   'Right Foot',
#   'Volley',
#   'Scott Malone',
#   'Pass (Dead)',
#   'Charlie Cresswell',
#   'Shot'],
#  ['8cdd19be',
#   '75',
#   'Jacob Brown',
#   'Stoke City',
#   '0.02',
#   '',
#   'Off Target',
#   '12',
#   'Right Foot',
#   'Volley',
#   'Connor Taylor',
#   'Pass (Live)',
#   'Lewis Baker',
#   'Pass (Dead)'],
#  ['8cdd19be',
#   '88',
#   'Benik Afobe',
#   'Millwall',
#   '0.09',
#   '',
#   'Blocked',
#   '13',
#   'Right Foot',
#   '',
#   'George Saville',
#   'Pass (Live)',
#   'Zian Flemming',
#   'Pass (Live)'],
#  ['8cdd19be',
#   '90+5',
#   'Jacob Brown',
#   'Stoke City',
#   '0.10',
#   '0.11',
#   'Saved',
#   '11',
#   'Head',
#   '',
#   'Gavin Kilkenny',
#   'Pass (Live)',
#   'Josh Laurent',
#   'Pass (Live)']]

# %%
#Flatten list one level to load into df
all_data = sum(all_data, [])

# %%
# Create a DataFrame from the scraped data
shots_df = pd.DataFrame(all_data, columns=headers)

# Add the team, away team, formation, and opponent formation information to the DataFrame
shots_df['Home_Team'] = home_team
shots_df['Away_Team'] = away_team
shots_df['Home Formation'] = home_formation
shots_df['Away Formation'] = away_formation
shots_df['is_home_shot'] = np.where(shots_df['Team'] == home_team, 1, 0)
shots_df['is_away_shot'] = np.where(shots_df['Team'] ==  away_team, 1, 0)
shots_df['location'] = location
shots_df['match_date'] = match_date
shots_df['competition'] = 'English Championship' #Can hard-code this since it will be the same throughout the df

# %%
shots_df
# Out:
#      Game_ID Minute             Player        Team    xG  PSxG      Result  \
# 0   46d9048f     11        Josh Cullen     Burnley  0.07  0.02       Saved
# 1   46d9048f     14      Ashley Barnes     Burnley  0.06  0.34       Saved
# 2   46d9048f     18        Ian Maatsen     Burnley  0.05  0.28        Goal
# 3   46d9048f     20     Connor Roberts     Burnley  0.21  0.88       Saved
# 4   46d9048f     24     Josh Brownhill     Burnley  0.03  0.20       Saved
# ..       ...    ...                ...         ...   ...   ...         ...
# 81  8cdd19be     65  Charlie Cresswell    Millwall  0.08  0.04       Saved
# 82  8cdd19be     65  Charlie Cresswell    Millwall  0.18  0.45        Goal
# 83  8cdd19be     75        Jacob Brown  Stoke City  0.02        Off Target
# 84  8cdd19be     88        Benik Afobe    Millwall  0.09           Blocked
# 85  8cdd19be   90+5        Jacob Brown  Stoke City  0.10  0.11       Saved
#
#    Distance   Body Part      Notes  ...       SCA 2 Player      Event 2  \
# 0        21   Left Foot             ...        Josh Cullen  Pass (Live)
# 1        14  Right Foot             ...     Josh Brownhill  Pass (Live)
# 2        15  Right Foot  Deflected  ...        Ian Maatsen  Pass (Live)
# 3         6  Right Foot     Volley  ...     Connor Roberts  Pass (Live)
# 4        18  Right Foot     Volley  ...
# ..      ...         ...        ...  ...                ...          ...
# 81        9        Head             ...
# 82        8  Right Foot     Volley  ...  Charlie Cresswell         Shot
# 83       12  Right Foot     Volley  ...        Lewis Baker  Pass (Dead)
# 84       13  Right Foot             ...      Zian Flemming  Pass (Live)
# 85       11        Head             ...       Josh Laurent  Pass (Live)
#
#    Home_Team   Away_Team Home Formation Away Formation is_home_shot  \
# 0   Millwall  Stoke City          3-4-3          3-5-2            0
# 1   Millwall  Stoke City          3-4-3          3-5-2            0
# 2   Millwall  Stoke City          3-4-3          3-5-2            0
# 3   Millwall  Stoke City          3-4-3          3-5-2            0
# 4   Millwall  Stoke City          3-4-3          3-5-2            0
# ..       ...         ...            ...            ...          ...
# 81  Millwall  Stoke City          3-4-3          3-5-2            1
# 82  Millwall  Stoke City          3-4-3          3-5-2            1
# 83  Millwall  Stoke City          3-4-3          3-5-2            0
# 84  Millwall  Stoke City          3-4-3          3-5-2            1
# 85  Millwall  Stoke City          3-4-3          3-5-2            0
#
#    is_away_shot         location  match_date
# 0             0  The Den, London  2022-07-30
# 1             0  The Den, London  2022-07-30
# 2             0  The Den, London  2022-07-30
# 3             0  The Den, London  2022-07-30
# 4             0  The Den, London  2022-07-30
# ..          ...              ...         ...
# 81            0  The Den, London  2022-07-30
# 82            0  The Den, London  2022-07-30
# 83            1  The Den, London  2022-07-30
# 84            0  The Den, London  2022-07-30
# 85            1  The Den, London  2022-07-30
#
# [86 rows x 22 columns]

# %%
#home team, away team, and formations are all messed up -- need to fix those

# %% [markdown]
# # To Do

# %% [markdown]
# 1. EDA
# 2. Start Modeling
